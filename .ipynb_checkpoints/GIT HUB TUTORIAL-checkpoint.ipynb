# %% [markdown]
# ![image.png](attachment:image.png)
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### use up arrow key for copy paste previous command

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### useful command
# - git config user.name
# - git config user.email

# %% [markdown]
# ### go to a folder , right click on the right cursor and clict " git bash here"
# ![image.png](attachment:image.png)

# %% [markdown]
# ### set up user name and gmail for GIT BASH
# ![image.png](attachment:image.png)

# %% [markdown]
# # Three stage architecture

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# - Staged means that you have marked a modified file in its current version to go into your next commit snapshot.
# - Git Commit It is used to record the changes in the repository. It is the next command after the git add. Every commit contains the index data and the commit message. Every commit forms a parent-child relationship. When we add a file in Git, it will take place in the staging area. A commit command is used to fetch updates from the staging area to the repository.

# %% [markdown]
# ### Tracking Our first Git Project

# %% [markdown]
# - first check out our git status using '' git status''
# - the we write 'git init' it will initializing the file and take it as a workign file
# ![image.png](attachment:image.png)

# %% [markdown]
# - the wirete again 'git status' it will show like this
# ![image.png](attachment:image.png)
# - add all the path in the staging in git hub github repositories
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# - commit our file and take a snapshot
# ![image.png](attachment:image.png)

# %% [markdown]
# - check our file by `git status`
# ![image.png](attachment:image.png)

# %% [markdown]
# - use `git log` to see commit
# ![image.png](attachment:image.png)
# - now let i change my `test_excel` file and add some data into it . the we use `git status` to show this result
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# - now i change some of text file again check up the status,you can see my text file change colour as red
# ![image.png](attachment:image.png)

# %% [markdown]
# - now i want to state my "test file.txt" then i add it to stage file
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)
